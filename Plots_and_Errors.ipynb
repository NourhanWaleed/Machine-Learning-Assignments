# %% [markdown]
# ### Very helpful notebook:
# https://www.kaggle.com/ravichaubey1506/complete-data-visualization-tutorial-seaborn

# %% [markdown]
# # 1. Scatter Plot

# %% [markdown]
# **Scatter plot** is the ordinary points plot on the X, y axeses. You can infere different relations between features using this plot.
# It is used to find the relation between 2 **Continuous Numerical** features and may help in classification problms to find if the features can give good information to help classify the output.
# See [This tutorial for more explanations](https://chartio.com/learn/charts/what-is-a-scatter-plot/)  or [this video](https://www.youtube.com/watch?v=ySdGUcyUe8U)

# %%
import seaborn as sns

# %%
iris_df = sns.load_dataset('iris')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# example
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris_df, hue='species')

# %% [markdown]
# In the previous scatter plot, we can deduce that:
# - setosa flowers tend to have lower sepal_length and higher sepal_width compared to the other species.
# - the sepal_width, sepal_legth features have a low positive correlation with each other

# %% [markdown]
# ### Now answer the follwing questions

# %% [markdown]
# **Question #1.1**

# %%
# make a scatterplot between the sepal_width, petal_width, then answer the questions
sns.scatterplot(x='sepal_width', y='petal_width', data=iris_df, hue='species')

# %% [markdown]
# 1- Is there a relation between petal_width and sepal_width features? if yes, is it positive or negative? and why?
#
# 2- How can you classify between species using these plot? ```[you can answer visually or with approximate numbers]```

# %% [markdown]
# **Question #1.2**

# %%
# make a scatter plot between petal_length on x axis, petal_width on y axis then answer the following questions
sns.scatterplot(x='petal_length', y='petal_width', data=iris_df, hue='species')

# %% [markdown]
#
# 1- What can you deduce from the previous scatter plot?

# %% [markdown]
# **Question #1.3**

# %%
# Run this cell, see the plot and answer the follwoing questions
sns.scatterplot(x='petal_length', y='petal_length', data=iris_df, hue='species')

# %% [markdown]
# 1- Why is this plot is shown as a linear line?
# 2- Can we deduce any information from this line?

# %% [markdown]
# ---

# %% [markdown]
# # 2. Histogram Plot
#
# **Histogram plot** is the a plot that shows the count of values for a **Categorical Feature** ```may be numerical or not```, it is commonly used as a density function estimation prestep and also to get sense of what is the value commonly used.
# You can think of it as a discretized distribution for some feature.
# See [This tutorial for more explanations](https://chartio.com/learn/charts/what-is-a-scatter-plot/) or [this video](https://www.youtube.com/watch?v=sC7gjg9g3JU)

# %%
import seaborn as sns
import math
import matplotlib as plt

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# #### Example

# %% [markdown]
# Let's plot the histogram for the total_bill feature.
# **NOTE** you may wonder how will we plot a histogram for a continuous numerical feature like total_bill?
# the answer is simple,, let's group each values within range of 1 together and make them a single value.
# for example: values ```[0.6, 0.95, 0.99, 1, 1.02, 1.1, 1.3, 1.45, 1.59, 1.8, 2.2, 2.3, 2.32]``` will be ```[1, 1, 1, 1, 1, 1, 1, 1, 2, 2, 2, 2]```, so we can calculate the histogram values like:
# ```count(1) = 8, count(2) = 4.... etc```

# %%
sns.histplot(x="total_bill", data=tips_df, binwidth=2);

tb=tips_df['total_bill']
mn = math.ceil(tips_df['total_bill'].min())
mx = math.ceil(tips_df['total_bill'].max()+1)
_ = plt.xticks(range(mn,mx,2), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9dd0e0d8932f> in <module>()
#       4 mn = math.ceil(tips_df['total_bill'].min())
#       5 mx = math.ceil(tips_df['total_bill'].max()+1)
# ----> 6 _ = plt.xticks(range(mn,mx,2), rotation=90)
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'

# %% [markdown]
# From this plot we can deduce the following:
# 1- The mode=17, **Mode** is the most occured value. Here the value 16 is occured around 32 times, which is the most occured value.
# 2- The total_bill distribution is right skewed, which means that the mean is greater than the mode and median values.

# %% [markdown]
# Now let's split the males records and the females records.

# %%
male_df = tips_df[tips_df['sex']=='Male'] # the bills that males paid

# %%
female_df = tips_df[tips_df['sex']=='Female'] # the bills that females paid

# %% [markdown]
# **Question #2.1**

# %%
# Plot the total_bill for male_df and answer the questions below
sns.histplot(x='total_bill', data=male_df, binwidth=2)

# refine plot x_ticks
tb=tips_df['total_bill']
mn = math.ceil(tips_df['total_bill'].min())
mx = math.ceil(tips_df['total_bill'].max()+1)
_ = plt.xticks(range(mn,mx,2), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-dca25d28bb35> in <module>()
#       6 mn = math.ceil(tips_df['total_bill'].min())
#       7 mx = math.ceil(tips_df['total_bill'].max()+1)
# ----> 8 _ = plt.xticks(range(mn,mx,2), rotation=90)
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'

# %% [markdown]
# 1- What is the mode value?
# 2- Is the distribution skewed? if yes, left or right? and what is that means?

# %% [markdown]
# **Question #2.2**

# %%
# Plot the total_bill for female_df and answer the questions below
sns.histplot(x='total_bill', data=female_df, binwidth=2)

# refine plot x_ticks
tb=tips_df['total_bill']
mn = math.ceil(tips_df['total_bill'].min())
mx = math.ceil(tips_df['total_bill'].max()+1)
_ = plt.xticks(range(mn,mx,2), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-56040d6cd41d> in <module>()
#       6 mn = math.ceil(tips_df['total_bill'].min())
#       7 mx = math.ceil(tips_df['total_bill'].max()+1)
# ----> 8 _ = plt.xticks(range(mn,mx,2), rotation=90)
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'

# %% [markdown]
# 1- What is the mode value?
# 2- Is the distribution skewed? if yes, left or right? and what is that means?
# 3- Do men pay more than women?
# 4- Do women pay when total_bill is greater than 46?

# %% [markdown]
# ---

# %% [markdown]
# # 3. Box Plot
#
# **Box plot** is a very famous plot that helps in detecting outliers and the see the distribution of a categorical feature.
# See [This tutorial for more explanations](https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51) or [this video](https://www.youtube.com/watch?v=fJZv9YeQ-qQ)

# %%
import seaborn as sns

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x="sex", y="total_bill", kind="box", data=tips_df);

# %% [markdown]
# From the previous plot we can deduce the following:
# 1- Males pay total_bill more than the Femals.
# 2- Males total_bill have around 4 outliers at values > 40.
# 3- Females have 4 outliers at values > 30.
# 4- The median value for the males is larger than the females.

# %% [markdown]
# **Question #3.1**

# %%
# Plot the box plots for each value of the 'size' feature on x value and 'total_bill' on y value
# size is the table size,, for example when size = 4, this mean that the total_bill is paied for a table that have 4 persons on it, .. etc
sns.catplot(x="size", y="total_bill", kind="box", data=tips_df);

# %% [markdown]
# 1- What is the size that have the hisghest median? can you think why this size is the highest?
# 2- Is size=1 has any outliers?
# 3- What size has the widest IQR?
# 4- See the box plots for each different table_size, do you see a relationship between the table size and the total_bill? describe this relationship?

# %% [markdown]
# ---

# %% [markdown]
# # 4. Trainning error vs testing error plot
# Run the following code cells and answer the questions at the last section.
# In this section we are plotting the result of different regression models using different polynomial degrees to fit the below data.
# When the degree of a polynomial icreases, the curve is fitting the data more, as you can see below.

# %%
import numpy as np
import pandas as pd

# Scikit-Learn for fitting models
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# For plotting in the notebook
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# Default parameters for plots
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.titlesize'] = 16
matplotlib.rcParams['figure.figsize'] = [9, 7]

# %%
# Set the random seed for reproducible results
np.random.seed(42)

# "True" generating function representing a process in real life
def true_gen(x):
    y = np.sin(1.2 * x * np.pi) 
    return(y)

# x values and y value with a small amount of random noise
x = np.sort(np.random.rand(120))
y = true_gen(x) + 0.1 * np.random.randn(len(x))

# %%
# Random indices for creating training and testing sets
random_ind = np.random.choice(list(range(120)), size = 120, replace=False)
xt = x[random_ind]
yt = y[random_ind]

# Training and testing observations
train = xt[:int(0.7 * len(x))]
test = xt[int(0.7 * len(x)):]

y_train = yt[:int(0.7 * len(y))]
y_test = yt[int(0.7 * len(y)):]

# Model the true curve
x_linspace = np.linspace(0, 1, 1000)
y_true = true_gen(x_linspace)

# %%
# Visualize observations and true curve
plt.plot(train, y_train, 'ko', label = 'Train'); 
plt.plot(test, y_test, 'ro', label = 'Test')
plt.legend()
plt.xlabel('x'); plt.ylabel('y'); plt.title('Data');

# %%
def fit_poly(train, y_train, test, y_test, degrees, plot='train', return_scores=False):
    
    # Create a polynomial transformation of features
    features = PolynomialFeatures(degree=degrees, include_bias=False)
    
    # Reshape training features for use in scikit-learn and transform features
    train = train.reshape((-1, 1))
    train_trans = features.fit_transform(train)
    
    # Create the linear regression model and train
    model = LinearRegression()
    model.fit(train_trans, y_train)
    
    # Calculate the cross validation score
    cross_valid = cross_val_score(model, train_trans, y_train, scoring='neg_mean_squared_error', cv = 5)
    
    # Training predictions and error
    train_predictions = model.predict(train_trans)
    training_error = mean_squared_error(y_train, train_predictions)
    
    # Format test features
    test = test.reshape((-1, 1))
    test_trans = features.fit_transform(test)
    
    # Test set predictions and error
    test_predictions = model.predict(test_trans)
    testing_error = mean_squared_error(y_test, test_predictions)
    
    # Find the model curve and the true curve
    x_curve = np.linspace(0, 1, 100)
    x_curve = x_curve.reshape((-1, 1))
    x_curve_trans = features.fit_transform(x_curve)
    
    # Model curve
    model_curve = model.predict(x_curve_trans)
    
    # True curve
    y_true_curve = true_gen(x_curve[:, 0])
    
    # Plot observations, true function, and model predicted function
    if plot == 'train':
        plt.plot(train[:, 0], y_train, 'ko', label = 'Observations')
        # plt.plot(x_curve[:, 0], y_true_curve, linewidth = 4, label = 'True Function')
        plt.plot(x_curve[:, 0], model_curve, linewidth = 4, label = 'Model Function')
        plt.xlabel('x'); plt.ylabel('y')
        plt.legend()
        plt.ylim(-1, 1.5); plt.xlim(0, 1)
        plt.title('{} Degree Model on Training Data'.format(degrees))
        plt.show()
        
    elif plot == 'test':
        # Plot the test observations and test predictions
        plt.plot(test, y_test, 'o', label = 'Test Observations')
        # plt.plot(x_curve[:, 0], y_true_curve, 'b-', linewidth = 2, label = 'True Function')
        plt.plot(test, test_predictions, 'ro', label = 'Test Predictions')
        plt.ylim(-1, 1.5); plt.xlim(0, 1)
        plt.legend(), plt.xlabel('x'), plt.ylabel('y'); plt.title('{} Degree Model on Testing Data'.format(degrees)), plt.show();

    elif plot == 'all':
        plt.plot(train, y_train, 'ko', label = 'Train'); 
        plt.plot(test, y_test, 'ro', label = 'Test')
        plt.plot(x_curve[:, 0], model_curve, linewidth = 4, label = 'Model Function')
        plt.xlabel('x'); plt.ylabel('y')
        plt.legend()
        plt.ylim(-1, 1.5); plt.xlim(0, 1)
        plt.title('{} Degree Model on Training Data'.format(degrees))
        plt.show()
    
    # Return the metrics
    if return_scores:
        return training_error, testing_error, -np.mean(cross_valid)

# %%
training_error_list = []
testing_error_list = []
for degree in range(1,31):
  (training_error, testing_error, val) = fit_poly(train, y_train, test, y_test, degrees = degree, plot='all', return_scores=True)
  training_error_list.append(training_error)
  testing_error_list.append(testing_error)

# %%
plt.plot(training_error_list, label='train error')
plt.plot(testing_error_list, label='test error')
plt.xlabel('Polynomial Degree'); plt.ylabel('MSE')
plt.title('Mean Squared Error for each different polynomial degree')
plt.legend()

# %% [markdown]
# **Questions 4.1**
# 1- what is the meaning of the last plot?
# 2- How can we make benfits of this plot? ```hint: think of overfitting and underfitting```
# 3- What polynomial degree should we choose? and why?
