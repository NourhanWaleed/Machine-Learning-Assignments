# %% [markdown]
# # Deep forward Neural Network
# In this assignment you are required to use neural netowrk to solve the given classification problem.
# You are given a data for previous heart-attack patients, your target is to predict whether has heart-attack or not.
#
# ## Loading the data

# %%
# !gdown --id 1SwQyWARiB7lyg-UECpunH0rlwTcjvQgn
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SwQyWARiB7lyg-UECpunH0rlwTcjvQgn
# To: /content/data.csv
# 100% 9.03k/9.03k [00:00<00:00, 19.2MB/s]

# %%
import pandas as pd
import numpy as np
from tensorflow import keras
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
data = pd.read_csv('data.csv')

# %%
X,y = data[data.columns[0:13]], data[data.columns[13]]

# %%
data.shape
# Out:
# (242, 14)

# %%
data.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  242.000000  242.000000  242.000000  ...  242.000000  242.000000  242.000000
# mean    54.099174    0.677686    1.000000  ...    0.719008    2.318182    0.578512
# std      8.849038    0.468331    1.038671  ...    1.032446    0.612796    0.494821
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.000000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     60.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   42    1   2       130   180    0  ...      0      0.0      2   0     2       1
# 1   53    0   0       130   264    0  ...      0      0.4      1   0     2       1
# 2   41    0   2       112   268    0  ...      1      0.0      2   0     2       1
# 3   47    1   2       130   253    0  ...      0      0.0      2   0     2       1
# 4   42    1   0       140   226    0  ...      0      0.0      2   0     2       1
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Your turn
# 1- create your model using keras.
# 2- compile your model with ```loss='binary_crossentropy', metrics=['accuracy']```.
# 3- fit your model with number of epochs between 500-200.
# 4- run the test-data testing code below

# %%
model = Sequential()
model.add(Dense(12,input_dim=13, activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X,y,epochs=300,batch_size=10)
# Out:
# Epoch 1/300
# 25/25 [==============================] - 1s 2ms/step - loss: 31.6711 - accuracy: 0.5785
# Epoch 2/300
# 25/25 [==============================] - 0s 1ms/step - loss: 19.5864 - accuracy: 0.5785
# Epoch 3/300
# 25/25 [==============================] - 0s 2ms/step - loss: 10.4529 - accuracy: 0.5785
# Epoch 4/300
# 25/25 [==============================] - 0s 2ms/step - loss: 4.0593 - accuracy: 0.5785
# Epoch 5/300
# 25/25 [==============================] - 0s 2ms/step - loss: 0.9219 - accuracy: 0.6198
# Epoch 6/300
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5785
# Epoch 7/300
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6607 - accuracy: 0.6405
# Epoch 8/300
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6524 - accuracy: 0.6405
# Epoch 9/300
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6530 - accuracy: 0.6570
# Epoch 10/300
# ...

# %% [markdown]
# ## Test your code
# Run the following cells, and it will print the loss and the accuracy of your model on a hidden test dataset. Submit those results in the form.
# **Make sure that you have named the model object ```model``` or edit it below.**

# %%
# !gdown --id 1W-fyRJDy87Xpyel5pCxnxRji8OSuTVeT
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1W-fyRJDy87Xpyel5pCxnxRji8OSuTVeT
# To: /content/test.csv
# 100% 2.33k/2.33k [00:00<00:00, 2.08MB/s]

# %%
import pandas as pd
test_data = pd.read_csv('/content/test.csv')

# %%
# this will print the loss, and the accuracy, submit them in the form.
result = model.evaluate(test_data.drop('target', axis=1), test_data['target'])
loss, accuracy = result[0], result[1]
print("Loss: " + str(loss) + "  -   Accuracy: " + str(accuracy))
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4845 - accuracy: 0.8361
# Loss: 0.48445454239845276  -   Accuracy: 0.8360655903816223
